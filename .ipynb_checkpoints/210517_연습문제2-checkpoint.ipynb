# %%
import urllib.parse

import pandas as pd

# %%
MARKET_CODE_DICT = {

    'kospi': 'stockMkt',

    'kosdaq': 'kosdaqMkt',

    'konex': 'konexMkt'

}

DOWNLOAD_URL = 'https://kind.krx.co.kr/corpgeneral/corpList.do'

# %%
def zeroFill(columnValue):    # 원하는 종목코드 가져오기

    columnValue = str(columnValue)

    outValue = columnValue.zfill(6)

    return outValue

# %%
def get_stock_codes(market=None, delisted=False):

    params = {'method': 'download'}

    if market.lower() in MARKET_CODE_DICT:

        ## marketType 키 추가

        params['marketType'] = MARKET_CODE_DICT[market]

        print(market.lower()+" market key is exist")

    else:

        print("invalid market")

    # make url  key=value & key = value

    params_string = urllib.parse.urlencode(params)

    request_url = DOWNLOAD_URL+"?"+params_string

    df = pd.read_html(request_url)[0]

    df["종목코드"] = df.종목코드.apply(zeroFill)
#     df["종목코드"] = df.종목코드.map('{:06d}'.format) # 동일 결과
 
    return df

# %%
stocks = get_stock_codes('kospi')

# stocks.head(2)
stocks
# Out:
# kospi market key is exist
#             회사명    종목코드              업종  \
# 0         DRB동일  004840        고무제품 제조업
# 1           DSR  155660     1차 비철금속 제조업
# 2         GS글로벌  001250       상품 종합 도매업
# 3     HDC현대산업개발  294870          건물 건설업
# 4           KEC  092220         반도체 제조업
# ..          ...     ...             ...
# 800     현대코퍼레이션  011760       상품 종합 도매업
# 801  현대코퍼레이션홀딩스  227840  음·식료품 및 담배 도매업
# 802          화신  010690   자동차 신품 부품 제조업
# 803         휴켐스  069260     기타 화학제품 제조업
# 804        흥국화재  000540             보험업
#
#                                                   주요제품         상장일  결산월  \
# 0                    고무벨트(V벨트,콘베이어벨트,평벨트),프라스틱제품 제조,판매  1976-05-21  12월
# 1                                               합섬섬유로프  2013-05-15  12월
# 2    수출입업(시멘트,철강금속,전기전자,섬유,기계화학),상품중개,광업,채석업/하수처리 서...  1976-06-26  12월
# 3                               외주주택, 자체공사, 일반건축, 토목 등  2018-06-12  12월
# 4                                               반도체 제조  2006-10-16  12월
# ..                                                 ...         ...  ...
# 800    자동차,철강,기계,선박,플랜트,컴퓨터,전자제품 수출,수출입대행/자원(탄광,유전) 개발  1977-12-01  12월
# 801                                        브랜드사업, 육류유통  2015-10-23  12월
# 802                      자동차엔진부품(ARM류,C/MBR류),자동차부품 제조  1994-01-14  12월
# 803                                        화합물,화학제품 제조  2002-10-07  12월
# 804                                               손해보험  1974-12-05  12월
#
#                       대표자명                                홈페이지     지역
# 0                      류영식                 http://drbworld.com  부산광역시
# 1                      홍석빈                  http://www.dsr.com  부산광역시
# 2                      김태형              http://www.gsgcorp.com  서울특별시
# 3                 권순호, 정경구              http://www.hdc-dvp.com  서울특별시
# 4                  박남규 김학남                http://www.kec.co.kr  서울특별시
# ..                     ...                                 ...    ...
# 800  정몽혁, 김원갑, 장안석(각자대표이사)        http://www.hyundaicorp.co.kr  서울특별시
# 801       정몽혁, 김원갑(각자대표이사)  http://www.hyundaicorpholdings.com  서울특별시
# 802               정서진, 장의호            http://www.hwashin.co.kr   경상북도
# 803                    신진용              http://www.huchems.com  서울특별시
# 804                    권중원          http://www.insurance.co.kr  서울특별시
#
# [805 rows x 9 columns]

# %%
# 매수/매도 결정 기본 예제 연습
stock_code = stocks.iloc[0]['종목코드']    #관심종목 변수정의
stock_name = stocks.iloc[0]['회사명']
print(stock_name)
print(stock_code)
# Out:
# DRB동일
# 004840

# %%
# 연습문제
# 특정회사명 종묙코드를 프린트하기

# %%
# 깔끔한 답
result = stocks[stocks['회사명'] == '삼성전자'].iloc[0]['종목코드']
result

# %%
# 내가 푼 거
searchStock = stocks['회사명'].str.contains("현대코퍼레이션")

search = stocks[searchStock]
search
# Out:
#             회사명    종목코드              업종  \
# 800     현대코퍼레이션  011760       상품 종합 도매업
# 801  현대코퍼레이션홀딩스  227840  음·식료품 및 담배 도매업
#
#                                                 주요제품         상장일  결산월  \
# 800  자동차,철강,기계,선박,플랜트,컴퓨터,전자제품 수출,수출입대행/자원(탄광,유전) 개발  1977-12-01  12월
# 801                                      브랜드사업, 육류유통  2015-10-23  12월
#
#                       대표자명                                홈페이지     지역
# 800  정몽혁, 김원갑, 장안석(각자대표이사)        http://www.hyundaicorp.co.kr  서울특별시
# 801       정몽혁, 김원갑(각자대표이사)  http://www.hyundaicorpholdings.com  서울특별시

# %%
searchCode = search.iloc[:,[0,1]]
searchCode
# Out:
#             회사명    종목코드
# 800     현대코퍼레이션  011760
# 801  현대코퍼레이션홀딩스  227840
